# %%
from matplotlib import pyplot as plt
import cv2
import glob

# %%
# load images (pngs)
images = glob.glob('../images/**.png')

# %% [markdown]
# ## loading images
#
# loading rgb images as rgb images and greyscale images.

# %%
# load as color image
img = cv2.imread(images[0], cv2.IMREAD_COLOR)

# load as grayscale
img_grey = cv2.imread(images[0], cv2.IMREAD_GRAYSCALE)

# %%
# display color and grayscale images
fig, axes = plt.subplots(1, 2, figsize=(8, 8), sharex=True, sharey=True)
ax = axes.ravel()

ax[0].set_title("Original color image")
ax[0].imshow(img[...,::-1], interpolation = "nearest")

ax[1].set_title("Image as grayscale")
ax[1].imshow(img_grey, cmap=plt.cm.Greys_r, interpolation = "nearest")

for a in ax:
    a.set_axis_off()

fig.tight_layout()
plt.show()

# %% [markdown]
# Alternatively, you can use integers (1, 0, -1) as flags *in lieu* of writing out `cv2.IMREAD_COLOR`, `cv2.IMREAD_GRAYSCALE`, *etc.*

# %%
# load color image
img = cv2.imread(images[0], 1)

# load as greyscale
img_grey = cv2.imread(images[0], 0)

# %% [markdown]
# ## Numpy and OpenCV
#
# With OpenCV, we work with large numpy arrays.
#
# - For **color** images, they are 3 dimensional arrays.
# - And **grayscale** images, they are 2 dimensional.

# %%
print('Color image\n-------\nImage shape: {}\ntype: {}\nData type: {}\nDimensions: {}'
      .format(img.shape, type(img), img.dtype, img.ndim)
     )
# Out:
# Color image
# -------
# Image shape: (512, 512, 3)
# type: <class 'numpy.ndarray'>
# Data type: uint8
# Dimensions: 3

# %%
print('Grayscale image\n-------\nImage shape: {}\ntype: {}\nData type: {}\nDimensions: {}'
      .format(img_grey.shape, type(img_grey), img_grey.dtype, img_grey.ndim)
     )
# Out:
# Grayscale image
# -------
# Image shape: (512, 512)
# type: <class 'numpy.ndarray'>
# Data type: uint8
# Dimensions: 2

# %% [markdown]
# ## Cropping images
#
# Okay, let's examine a small section of the image (region of interest (ROI)). Selecting the eye of the lenna.png.
#
# For our grayscaled image,
#
# - img_gray[0,0] = top-left pixel intensity value
#
# For the color image,
#
# - img[0,0,0] = top-left pixel value in our Blue channel (we'll discuss this below)

# %%
# select region of interest using numpy indexing
img_roi = img_grey[250:280, 240:295]

# %%
# plot  image
plt.title("Cropped Grayscaled image")
plt.imshow(img_roi, cmap=plt.cm.Greys_r, interpolation = "nearest")
plt.show()

# %%
print(img_roi)
# Out:
# [[199 197 180 ... 157 166 174]
#  [200 192 174 ... 131 146 158]
#  [197 188 169 ... 110 131 145]
#  ...
#  [149 144 146 ... 139 137 142]
#  [151 151 149 ... 137 143 144]
#  [151 156 146 ... 142 144 144]]

# %% [markdown]
# # Color format
#
# **BGR** –> Blue intensity, Green intensity, and Red intensity

# %%
# splitting the color channels
b, g, r = cv2.split(img)

# %%
# display color channels
fig, axes = plt.subplots(1, 3, figsize=(6, 6), sharex=True, sharey=True)
ax = axes.ravel()

ax[0].set_title("Blue Channel")
ax[0].imshow(b, cmap=plt.cm.Blues, interpolation = "nearest")

ax[1].set_title("Green Channel")
ax[1].imshow(g, cmap=plt.cm.Greens, interpolation = "nearest")

ax[2].set_title("Red Channel")
ax[2].imshow(r, cmap=plt.cm.Reds, interpolation = "nearest")

for a in ax:
    a.set_axis_off()

fig.tight_layout()
plt.show()

# %%
# recombine separated channels
recombined = cv2.merge((b, g, r))

# Recombine separated channels
plt.title("Recombined channels")
plt.imshow(recombined[...,::-1], interpolation = "nearest")
plt.show()

# %% [markdown]
# # Converting between color format
#
# The keen-eyed may have noticed that when plotting with matplotlib above, we reindexed our color image before plotting `img[...,::-1]`. OpenCV loads images in BGR mode, however, matplotlib and other software use RGB. Therefore, here, we reordered the image dimensions (the color channels) to reflect appear correctly.

# %%
# convert to rgb
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
# display original color and BGR converted image
fig, axes = plt.subplots(1, 2, figsize=(5, 3), sharex=True, sharey=True)
ax = axes.ravel()

ax[0].set_title("Original color image")
ax[0].imshow(img, interpolation = "nearest")

ax[1].set_title("Image converted to RGB")
ax[1].imshow(img_rgb, interpolation = "nearest")

for a in ax:
    a.set_axis_off()

fig.tight_layout()
plt.show()

# %% [markdown]
# # Resize images

# %%
img_resize = cv2.resize(img, (img.shape[0] // 2, img.shape[1] // 2), interpolation = cv2.INTER_CUBIC)

# %%
# Resizing image
plt.title("Resized Image")
plt.imshow(img_resize[...,::-1], interpolation = "nearest")
plt.show()

# %% [markdown]
# # Image transformations

# %%
# basic rotation
img_rot1 = cv2.rotate(img_grey, cv2.ROTATE_180)
img_rot2 = cv2.rotate(img_grey, cv2.ROTATE_90_CLOCKWISE)
img_rot3 = cv2.rotate(img_grey, cv2.ROTATE_90_COUNTERCLOCKWISE)

# display original color and BGR converted image
fig, axes = plt.subplots(1, 4, figsize=(12, 3), sharex=True, sharey=True)
ax = axes.ravel()

ax[0].set_title("Original color image")
ax[0].imshow(img_grey, cmap = plt.cm.gray, interpolation = "nearest")

ax[1].set_title("180 degree rotation")
ax[1].imshow(img_rot1, cmap = plt.cm.gray, interpolation = "nearest")

ax[2].set_title("90 degree clockwise rotation")
ax[2].imshow(img_rot2, cmap = plt.cm.gray, interpolation = "nearest")

ax[3].set_title("90 degree counterclockwise rotation")
ax[3].imshow(img_rot3, cmap = plt.cm.gray, interpolation = "nearest")


for a in ax:
    a.set_axis_off()

fig.tight_layout()
plt.show()

# %%
M = cv2.getRotationMatrix2D((img_grey.shape[0]//2 , img_grey.shape[1]// 2), 180, 1)
img_rot = cv2.warpAffine(img_grey, M, (img_grey.shape[0], img_grey.shape[1]))
# Out:
# array([[-1.0000000e+00,  1.2246468e-16,  1.0240000e+03],
#        [-1.2246468e-16, -1.0000000e+00,  1.0240000e+03]])

# %%
# translation
img_trl
